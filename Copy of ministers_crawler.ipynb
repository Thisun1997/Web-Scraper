# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 254 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 251 kB 46.4 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 46.3 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 56.1 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.0 MB/s
# ...
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7782 sha256=2bd0a064c4fa47b32557ce56c9400a9fab932d02f6d71176c2a4a702b44cd233
#   Stored in directory: /root/.cache/pip/wheels/ca/44/01/3592ccfbcfaee4ab297c4097e6e9dbe1c7697e3531a39877ab
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11515 sha256=7770d5ff3d5cbcdb6bdbcb0b653686ecfc02bcc23ebdda631c55f95d9c334eab
# ...

# %%
# !scrapy startproject crawler
# Out:
# New Scrapy project 'crawler', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/MyDrive/DMIR/crawler
#
# You can start your first spider with:
#     cd crawler
#     scrapy genspider example example.com

# %%
# %cd /content/drive/MyDrive/DMIR/crawler/
# Out:
# /content/drive/MyDrive/DMIR/crawler

# %%
# !scrapy crawl districts
# Out:
# 2021-10-22 17:47:17 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: crawler)
# 2021-10-22 17:47:17 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-10-22 17:47:17 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-10-22 17:47:17 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler',
#  'NEWSPIDER_MODULE': 'crawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler.spiders']}
# 2021-10-22 17:47:17 [scrapy.extensions.telnet] INFO: Telnet Password: ddd1616b367c6fdf
# 2021-10-22 17:47:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# !scrapy crawl quotes -O quotes_songs.json

# %%
# !scrapy shell 'http://www.manthri.lk/si/politicians/tiran-alles'
# Out:
# 2021-10-14 05:06:45 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: crawler)
# 2021-10-14 05:06:45 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 35.0.0, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-10-14 05:06:45 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-10-14 05:06:45 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawler',
#  'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0,
#  'NEWSPIDER_MODULE': 'crawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['crawler.spiders']}
# 2021-10-14 05:06:45 [scrapy.extensions.telnet] INFO: Telnet Password: c4e8da4da7c2444d
# 2021-10-14 05:06:45 [scrapy.middleware] INFO: Enabled extensions:
# ...

# %%
# !scrapy shell "http://www.manthri.lk//si/politicians/buddhika-pathirana"
# Out:
# 2021-09-28 17:18:52 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-09-28 17:18:52 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 3.4.8, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-09-28 17:18:52 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-09-28 17:18:52 [scrapy.crawler] INFO: Overridden settings:
# {'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter',
#  'LOGSTATS_INTERVAL': 0}
# 2021-09-28 17:18:52 [scrapy.extensions.telnet] INFO: Telnet Password: f5bbd38df87fd136
# 2021-09-28 17:18:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage']
# ...
